# %%
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential

# %%
model=Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
def params(hp):
    model=Sequential()
    model.add(Conv2D(unit=hp.Int("unit",min_value=22,max_value=123,activation="relu",kerel_shape=(3,3),input_size=(128,128,3),pooling="same")))
    model.add(Droupout(0.2)
    model.add(Conv2D(unit=hp.Int("uint",min_value=22,max_value=123,activation="relu",kerel_shape=(3,3),input_size=(128,128,3),pooling="same")))
    model.add(MaxPooling(22,kernel_size=(3,3),activation="relu",))
    model.add(Flatten())
    model.add(128,activation="relu")
    model.add(1,activation="softmax")
