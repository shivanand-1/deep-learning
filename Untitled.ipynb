# %%
from sklearn.datasets import make_classification
import pandas as pd

# %%
x,y=make_classification(n_samples=1000,n_features=2,n_redundant=0)

# %%
import matplotlib.pyplot as plt 
plt.scatter(x[:,0],x[:,-1],c=y)

# %%
from mlxtend.plotting import plot_decision_regions
import sklearn.linear_model as lm
from sklearn.linear_model import Perceptron
model=Perceptron()
king=model.fit(x,y)
print(x)
# Out:
# [[ 1.53018112 -1.5240485 ]
#  [ 1.12873809  0.33721368]
#  [ 0.8094422  -0.74228589]
#  ...
#  [-0.02001195  0.43813628]
#  [ 1.01932355 -1.03618186]
#  [-0.90533273  0.74033599]]

# %%
plot_decision_regions(x,y,clf=model)
# Out:
# <Axes: >

# %%
import numpy as np
x=np.insert(x,0,1,axis=1)
x=list(x)
# Out:
# 1.0

# %%
xu
for i in x:
    print(i[6:].append(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 3
#       1 x
#       2 for i in x:
# ----> 3     print(i[6:].append(x))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
import pandas as pd

data = {
    "Name": ["Ram", "Sham", "John", "Aman"],
    "Marks": [85, 90, 78, 92]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Marks
# 0   Ram     85
# 1  Sham     90
# 2  John     78
# 3  Aman     92

# %%
df.shape[0]
# Out:
# 4

# %%
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights=np.once(x.shape[1])
    lr=0.4
    for i in range(1000):
        k=random.randint(x)
