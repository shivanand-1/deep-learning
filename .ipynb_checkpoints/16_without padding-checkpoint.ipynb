# %%
from tensorflow.keras.layers import Conv2D,Flatten,Dense
from tensorflow.keras.datasets import mnist as mt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential

# %%
model=Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.add(Conv2D(32,activation="relu",input_shape=(124,124,3),padding="valid",kernel_size=(3,3)))

# %%
model.add(Conv2D(32,activation="relu",padding="valid",kernel_size=(3,3)))
model.add(Conv2D(32,activation="relu",padding="valid",kernel_size=(3,3)))
model.add(Flatten())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 122, 122, 32)      896
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 32)      9248
#
#  conv2d_3 (Conv2D)           (None, 118, 118, 32)      9248
#
#  conv2d_4 (Conv2D)           (None, 116, 116, 32)      9248
#
#  conv2d_5 (Conv2D)           (None, 114, 114, 32)      9248
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 32)      9248
#
#  conv2d_7 (Conv2D)           (None, 110, 110, 32)      9248
#
#  conv2d_8 (Conv2D)           (None, 108, 108, 32)      9248
#
#  flatten (Flatten)           (None, 373248)            0
#
# ...
# Total params: 65632 (256.38 KB)
# Trainable params: 65632 (256.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.add(Dense(128,activation="relu"))
model.add(Dense(32,activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_1 (Conv2D)           (None, 122, 122, 32)      896
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 32)      9248
#
#  conv2d_3 (Conv2D)           (None, 118, 118, 32)      9248
#
#  conv2d_4 (Conv2D)           (None, 116, 116, 32)      9248
#
#  conv2d_5 (Conv2D)           (None, 114, 114, 32)      9248
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 32)      9248
#
#  conv2d_7 (Conv2D)           (None, 110, 110, 32)      9248
#
#  conv2d_8 (Conv2D)           (None, 108, 108, 32)      9248
#
#  flatten (Flatten)           (None, 373248)            0
#
#  dense (Dense)               (None, 128)               47775872
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 32)                4128
#
# ...
# Total params: 47862144 (182.58 MB)
# ...

# %%
print(mt)
# Out:
# <module 'keras.api._v2.keras.datasets.mnist' from 'C:\\Users\\shiva\\anaconda3\\Lib\\site-packages\\keras\\api\\_v2\\keras\\datasets\\mnist\\__init__.py'>

# %%
model.add(Conv2D(32,activation="relu",input_shape=(124,124,3),padding="same",kernel_size=(3,3)))
model.add(Conv2D(32,activation="relu",padding="same",kernel_size=(3,3)))
model.add(Conv2D(32,activation="relu",padding="same",kernel_size=(3,3)))
model.add(Flatten())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.add(Conv2D(32,activation="relu",input_shape=(124,124,3),padding="same",kernel_size=(3,3)))
#       2 model.add(Conv2D(32,activation="relu",padding="same",kernel_size=(3,3)))
#       3 model.add(Conv2D(32,activation="relu",padding="same",kernel_size=(3,3)))
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\trackable\base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ...
