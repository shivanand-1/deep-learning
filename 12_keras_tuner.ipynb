# %%
from tensorflow import keras as ks
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\shiva\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ['Input',
#  'Model',
#  'Sequential',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__internal__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'activations',
#  'applications',
#  'backend',
#  'callbacks',
#  'constraints',
#  'datasets',
#  'dtensor',
#  'estimator',
#  'experimental',
#  'export',
#  'initializers',
#  'layers',
#  'losses',
#  'metrics',
#  'mixed_precision',
#  'models',
#  'optimizers',
#  'preprocessing',
#  'regularizers',
#  'saving',
#  'utils']

# %%
# !pip install -U keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in C:\Users\shiva\anaconda3\Lib\site-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in C:\Users\shiva\anaconda3\Lib\site-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in C:\Users\shiva\anaconda3\Lib\site-packages (from keras-tuner) (2.32.5)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in C:\Users\shiva\anaconda3\Lib\site-packages (from keras-tuner) (1.74.0)
# Requirement already satisfied: protobuf in C:\Users\shiva\anaconda3\Lib\site-packages (from keras-tuner) (4.25.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\shiva\anaconda3\Lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\shiva\anaconda3\Lib\site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\shiva\anaconda3\Lib\site-packages (from requests->keras-tuner) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\shiva\anaconda3\Lib\site-packages (from requests->keras-tuner) (2025.1.31)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
#
#    ---------------------------------------- 0/2 [kt-legacy]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    -------------------- ------------------- 1/2 [keras-tuner]
#    ---------------------------------------- 2/2 [keras-tuner]
#
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~onttools (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~onttools (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~onttools (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import pandas as pd
import keras_tuner as tf

# %%
data=load_iris()

# %%
X=data.data

# %%
y=data.target

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)

# %%
def parameter(hp):
    model=Sequential()
    union=hp.Int("union",min_value=1,max_value=129)
    model.add(Dense(union,activation="softmax"))
    model.add(Dense(1,activation="sigmoid"))
    model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
    return model

# %%
tuner=tf.RandomSearch(parameter,objective="val_accuracy",max_trials=5)
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
tuner.get_best_models
# Out:
# <bound method Tuner.get_best_models of <keras_tuner.src.tuners.randomsearch.RandomSearch object at 0x0000024E6286F350>>
