# %% [raw]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# %%
or_data=pd.DataFrame()
and_data=pd.DataFrame()
xor_data=pd.DataFrame()

# %%
or_data["input1"]=[0,0,1,1]
or_data["input2"]=[0,1,0,1]
or_data["output"]=[0,0,0,1]

# %%
and_data["input1"]=[0,0,1,1]
and_data["input2"]=[0,1,0,1]
and_data["output"]=[0,1,1,1]

# %%
xor_data["input1"]=[0,0,1,1]
xor_data["input2"]=[0,1,0,1]
xor_data["output"]=[1,0,0,1]

# %%
plt.scatter(or_data["input1"],or_data["input2"],c=or_data["output"])
l=Perceptron()
x=np.linspace(-1,1,100)
y=-x+1
plt.plot(x,y)
model1=l.fit(or_data.iloc[:,:2].values,or_data.iloc[:,-1].values)
print(model1.coef_)
print(model1.intercept_)
# Out:
# [[2. 2.]]
# [-2.]

# %%
w1 = model1.coef_[0][0]
w2 = model1.coef_[0][1]
b = model1.intercept_[0]

x1 = np.linspace(-1,2,100)
x2 = -(w1*x1 + b)/w2

plt.scatter(or_data["input1"],
            or_data["input2"],
            c=or_data["output"])

plt.plot(x1, x2)

plt.xlim(-1,2)
plt.ylim(-1,2)

plt.grid(True)
plt.show()

# %%
plt.scatter(and_data["input1"],and_data["input2"],c=and_data["output"])

# %%
plt.scatter(xor_data["input1"],xor_data["input2"],c=xor_data["output"])
model3=l.fit(xor_data.iloc[:,0:2].values,y=xor_data.iloc[:,-1].values)
w1=model3.coef_[0][0]
w2=model3.coef_[0][1]
b=model3.intercept_
x=np.linspace(-10,10,100)
x2 = -(w1 * x1 + b) / w2
plt.plot(x,x2)
plt.title("xor is not fit for non liearn")
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_23064\1235320171.py:7: RuntimeWarning: invalid value encountered in divide
#   x2 = -(w1 * x1 + b) / w2

# %%
from sklearn.linear_model import Perceptron
l=Perceptron()

# %%
model1=l.fit(or_data.iloc[:,:2].values,or_data.iloc[:,-1].values)
print(model1.coef_)
print(model1.intercept_)
# Out:
# [[2. 2.]]
# [-2.]

# %%
model2=l.fit(xor_data.iloc[:,:2].values,xor_data.iloc[:,-1].values)
print(model2.coef_)
print(model2.intercept_)
# Out:
# [[0. 0.]]
# [0.]

# %%
w1 = model1.coef_[0][0]
w2 = model1.coef_[0][1]
b = model1.intercept_[0]

# %%
plt.scatter(xor_data["input1"],xor_data["input2"],c=xor_data["output"])

x1=np.linspace(-1,10,100)
x2 = -(w1 * x1 + b) / w2
plt.plot(x1, x2)
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Perceptron Decision Boundary")

plt.xlim(-1,2)
plt.ylim(-1,2)
# Out:
# (-1.0, 2.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.scatter(or_data["input1"],
            or_data["input2"],
            c=or_data["output"])

w1 = model.coef_[0][0]
w2 = model.coef_[0][1]
b = model.intercept_[0]

if w2 != 0:
    x1 = np.linspace(-1, 2, 100)
    x2 = -(w1 * x1 + b) / w2
    plt.plot(x1, x2)

else:
    # vertical line
    x = -b / w1
    plt.axvline(x=x)

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Perceptron Decision Boundary")

plt.xlim(-1,2)
plt.ylim(-1,2)

plt.grid(True)
plt.show()

# %%
def perceptron(X,y):
    w1=w2=b=1
    lr=0.1
    for i in range(X.shape[):
        z=w1*X[i][0]+w2*X[i][1]+b   
        if z*y[i]>0:
            w1=w1+lr*y[i]*X[i][0]
            w2=w2+lr*y[i]*X[i][1]
            b=b+lr*y[i]
    return w1,w2,b
w1,w2,b=perceptron(X,y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 11
#       9             b=b+lr*y[i]
#      10     return w1,w2,b
# ---> 11 w1,w2,b=perceptron(X,y)
#
# Cell In[74], line 5, in perceptron(X, y)
#       3 lr=0.1
#       4 for i in range(1000):
# ----> 5     z=w1*X[i][0]+w2*X[i][1]+b
#       6     if z*y[i]>0:
#       7         w1=w1+lr*y[i]*X[i][0]
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
m=-(w1/w2)
c=-(b/w2)

# %%
import numpy as np
x_input=np.linspace(-3,3,1000)
y_input=m*x_input+c
plt.scatter(x_input,y_input,color='red',s=0.8)

plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=10)#s is means is the size
