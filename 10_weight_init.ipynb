# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("ushape.csv")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          X       Y  class
# 0   0.0316  0.9870    0.0
# 1   2.1200 -0.0462    1.0
# 2   0.8820 -0.0758    0.0
# 3  -0.0551 -0.0373    1.0
# 4   0.8300 -0.5390    1.0
# ..     ...     ...    ...
# 95  1.7000  0.5880    1.0
# 96  0.2190 -0.6530    1.0
# 97  0.9530 -0.4200    1.0
# 98 -1.3200  0.4230    0.0
# 99 -1.3000  0.1840    0.0
#
# [100 rows x 3 columns]

# %%
plt.scatter(df["X"],df["Y"],c=df.iloc[:,-1])

# %%
X=df.iloc[:,0:2]

# %%
y=df.iloc[:,-1]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from sklearn.model_selection import train_test_split
import tensorflow

# %%
model=Sequential()

# %%
model.add(Dense(2,activation="relu",input_dim=2))
model.add(Dense(1,activation="relu"))

# %% [markdown]
# model.summary()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 2)                 6
#
#  dense_15 (Dense)            (None, 1)                 3
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 123)               369
#
#  dense_7 (Dense)             (None, 123)               15252
#
#  dense_8 (Dense)             (None, 1)                 124
#
# ...
# Total params: 15745 (61.50 KB)
# Trainable params: 15745 (61.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
initiliazation=model.get_weights()

# %%
initiliazation
# Out:
# [array([[ 0.26468194,  0.31456053],
#         [ 0.423293  , -0.57559335]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-1.23982  ],
#         [ 0.8182858]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initiliazation[0]=np.zeros(model.get_weights()[0].shape)
initiliazation[1]=np.zeros(model.get_weights()[1].shape)
initiliazation[2]=np.zeros(model.get_weights()[2].shape)
initiliazation[3]=np.zeros(model.get_weights()[3].shape)

# %%
initiliazation
# Out:
# [array([[0., 0.],
#         [0., 0.]]),
#  array([0., 0.]),
#  array([[0.],
#         [0.]]),
#  array([0.])]

# %%
model.set_weights(initiliazation)

# %%
np.ones(model.get_weights()[0].shape)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %% [markdown]
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 2s 15ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 8ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 6/100
# ...

# %%
model.score(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 model.score(X_train,y_train)
#
# AttributeError: 'Sequential' object has no attribute 'score'

# %%
loss, accuracy = model.evaluate(X_train, y_train)

print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 2/2 [==============================] - 0s 19ms/step - loss: 6.6841 - accuracy: 0.5667
# Loss: 6.684144020080566
# Accuracy: 0.5666666626930237

# %%
avg=df.iloc[:,-1].sum()/df.iloc[:,-1].count()

# %%
np.full(model.get_weights()[0].shape,avg)
# Out:
# array([[0.5, 0.5],
#        [0.5, 0.5]])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype(int),clf=model,legend=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 2
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(X,y.astype(int),clf=model,legend=2)
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:161, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#      50 def plot_decision_regions(
#      51     X,
#      52     y,
#    (...)
#      72     n_jobs=None,
#      73 ):
#      74     """Plot decision regions of a classifier.
#      75
#      76     Please note that this functions assumes that class labels are
#    (...)
#     158
#     159     """
# ...

# %%
from mlxtend.plotting import plot_decision_regions

X_np = X.to_numpy()
y_np = y.to_numpy().astype(int)

plot_decision_regions(X_np, y_np, clf=model, legend=2)
# Out:
# 9600/9600 [==============================] - 42s 4ms/step
# <Axes: >
