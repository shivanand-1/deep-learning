# %%
import pandas as pd
import numpy as np

# %%
random=np.random.randint(1,12)
print(random)
# Out:
# 5

# %%
# !pip install transformers
# Out:
# ...
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transfomers.keras import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from transfomers.keras import Sequential
#
# ModuleNotFoundError: No module named 'transfomers'

# %%
import pandas as pd

# DataFrame
df = pd.DataFrame({
    "Hours_Studied": [1, 2, 3, 4, 5],
    "Marks": [35, 45, 55, 65, 75]
})
df
# Out:
#    Hours_Studied  Marks
# 0              1     35
# 1              2     45
# 2              3     55
# 3              4     65
# 4              5     75

# %%
from tensorflow.keras.models import Sequential
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def initization(layer_dims):
    dimensions={}
    for i in range(1,len(layer_dims)):
        dimensions["w"+str(i)]=np.ones((layer_dims[i-1],layer_dims[0]))*0.1
        dimensions["b",str(i)]=np.zeros((layer_dims[1],1))
    return dimensions

# %%
initization([2,2,1])
# Out:
# {'w1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  ('b',
#   '1'): array([[0.],
#         [0.]]),
#  'w2': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  ('b',
#   '2'): array([[0.],
#         [0.]])}

# %%
def linear_forword(prev,w,b):
    x=np.dot((prev,w))+b
    return x

# %%
def l_forword(X,forword):
    A=X
    l=len(parameter)//2
    for i in range(1,len)

# %%
from keras import Sequential
from keras.layers import Dense

# %%
df
# Out:
#    Hours_Studied  Marks
# 0              1     35
# 1              2     45
# 2              3     55
# 3              4     65
# 4              5     75

# %%
model=Sequential()
model.add(Dense(2,activation="linear",input_dim=2))
model.add(Dense(1,activation="linear"))
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.6373164 ,  0.25509322],
#         [ 0.6129199 ,  0.7763437 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.9785317 ],
#         [0.74367535]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
set_weights=[np.array([[0.1,0.1],[0.1,0.1]],dtype=np.float32),np.array([[0],[0]],dtype=np.float32),
             np.arry([[0.1],[0.1]],dtype=np.float32),np.array([0],dtype=np.float32)]
# Out:
#   Cell In[15], line 2
#     np.arry([[0.1],[0.1]],dtype=np.float32,np.array([0],dtype=np.float32)]
#                                                                          ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
import numpy as np

set_weights = [
    np.array([[0.1, 0.1],
              [0.1, 0.1]], dtype=np.float32),  # W1

    np.array([0, 0], dtype=np.float32),        # b1

    np.array([[0.1],
              [0.1]], dtype=np.float32),       # W2

    np.array([0], dtype=np.float32)            # b2
]

# %%
model.set_weights(set_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
from keras.optimizers import Adam

# %%
kin=Adam(learning_rate=0.01)

# %%
model.compile(loss="mean_squared_error",optimizer=kin)

# %%
X = df["Hours_Studied"].values.reshape(-1,1)
y = df["Marks"].values

# %%
model.fit(X,y,epochs=75)
# Out:
# Epoch 1/75
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 model.fit(X,y,epochs=75)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filefl7ythbd.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

model.add(Dense(2, input_dim=1, activation='linear'))
model.add(Dense(1, activation='linear'))

model.compile(
    optimizer='adam',
    loss='mse'
)
# Out:
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
X = df["Hours_Studied"].values.reshape(-1,1)
y = df["Marks"].values

model.fit(X, y, epochs=75)
# Out:
# Epoch 1/75
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 2s 2s/step - loss: 3423.3406
# Epoch 2/75
# 1/1 [==============================] - 0s 31ms/step - loss: 3421.8086
# Epoch 3/75
# 1/1 [==============================] - 0s 23ms/step - loss: 3420.2766
# Epoch 4/75
# 1/1 [==============================] - 0s 18ms/step - loss: 3418.7449
# Epoch 5/75
# 1/1 [==============================] - 0s 37ms/step - loss: 3417.2141
# Epoch 6/75
# 1/1 [==============================] - 0s 14ms/step - loss: 3415.6831
# Epoch 7/75
# 1/1 [==============================] - 0s 16ms/step - loss: 3414.1528
# Epoch 8/75
# 1/1 [==============================] - 0s 15ms/step - loss: 3412.6226
# Epoch 9/75
# 1/1 [==============================] - 0s 16ms/step - loss: 3411.0930
# Epoch 10/75
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 2)                 4
#
#  dense_3 (Dense)             (None, 1)                 3
#
# ...
# Total params: 7 (28.00 Byte)
# Trainable params: 7 (28.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_pred=model.predict(X)
# Out:
# 1/1 [==============================] - 0s 205ms/step

# %%
model.evaluate(X,y)
# Out:
# 1/1 [==============================] - 0s 304ms/step - loss: 3309.4751
# 3309.47509765625

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y,color="blue")
plt.scatter(X,y_pred,color="red")

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y, y_pred)
print(r2)
# Out:
# -15.547374725341797

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\shiva\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 [==============================] - 2s 2s/step - loss: 848.3722 - accuracy: 0.0000e+00
# Epoch 2/50
# 1/1 [==============================] - 0s 22ms/step - loss: 848.3722 - accuracy: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 0s 19ms/step - loss: 848.3722 - accuracy: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 0s 18ms/step - loss: 848.3722 - accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 0s 36ms/step - loss: 848.3722 - accuracy: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 0s 33ms/step - loss: 848.3722 - accuracy: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 0s 21ms/step - loss: 848.3722 - accuracy: 0.0000e+00
# ...

# %%
y_pred=model.predict(X)
plt.scatter(X,y,color="red")
plt.scatter(X,y_pred,color="blue")
# Out:
# 1/1 [==============================] - 0s 130ms/step
