# %%
import  transformers.Kerase.models import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import  transformers.Keras as kr
#       2 dir(kr)
#
# ModuleNotFoundError: No module named 'transformers.Keras'

# %%
from tensorflow.keras import tf
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from tensorflow.keras import tf
#       2 from tensorflow.keras.models import Sequential
#
# ImportError: cannot import name 'tf' from 'tensorflow.keras' (C:\Users\shiva\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py)

# %%
# !pip install tensorflow.keras import tf
# Out:
# ...
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement import (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for import

# %%
from tensorflow.keras import tf
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from tensorflow.keras import tf
#       2 from tensorflow.keras.models import Sequential
#
# ImportError: cannot import name 'tf' from 'tensorflow.keras' (C:\Users\shiva\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py)

# %%
# !pip install tensorflow
# Out:
# ...
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5py (C:\Users\shiva\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\shiva\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras import tf
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from tensorflow.keras import tf
#       2 from tensorflow.keras.models import Sequential
#
# ImportError: cannot import name 'tf' from 'tensorflow.keras' (C:\Users\shiva\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow.keras.models as ts
dir(ts)
# Out:
# ['Model',
#  'Sequential',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'clone_model',
#  'experimental',
#  'load_model',
#  'model_from_config',
#  'model_from_json',
#  'model_from_yaml',
#  'save_model']

# %%
import numpy as np

# %%
x=np.array([1,2,3,4,5],dtype="float64")
y=np.array([2,3,4,56,4],dtype='float64')
model=Sequential()

# %% [markdown]
# model.add(Desne(5,activation="relu",input_dim=1)
# mdoel.add(Dense(1)
# model.compile(optimizer='adam',
#               loss='mean_squared_error')

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.fit(x,y)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:3983, in Model._assert_compile_was_called(self)
#    3977 def _assert_compile_was_called(self):
#    3978     # Checks whether `compile` has been called. If it has been called,
#    3979     # then the optimizer is set. This is different from whether the
#    3980     # model is compiled
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
print("Working")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Working

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

print("LangChain Working")
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_77664\372359311.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# LangChain Working
